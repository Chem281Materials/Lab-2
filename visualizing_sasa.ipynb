# %%
import sasa_viz as sv

# 1. Fetch & parse structure
filepath = sv.fetch_pdb("1CRN")
structure = sv.load_structure(filepath, structure_id="1CRN")

# 2. Analyze & render
analyzed_struct, total_sasa = sv.analyze_sasa(structure, filepath)
sv.render_sasa(analyzed_struct).show()

# %%
import sasa_viz as sv

local_file = "data/2DAN.pdb"

# Load local file without network access
structure = sv.load_structure(local_file, structure_id="local_protein")
analyzed_struct, total_sasa = sv.analyze_sasa(structure, local_file)

sv.render_sasa(analyzed_struct).show()
